# %%
import typing 
import List
import random
import math
class Kmeans:
    def __init__(self,k,max_iter,lr,seed=42):
        self.k=k
        self.maxiterations=max_iter
        self.lr=lr 
        self.seed=seed 
    def fit(self,X):
        if not X:
            return []
        random.seed(self.seed)
        n=len(X)
        d=len(X[0])

stack=[]
stack.pop()
stack.append()
deque=collections.deque()
deque.popleft()
deque.append
